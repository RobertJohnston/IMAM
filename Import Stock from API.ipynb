# %%
from temba_client.v2 import TembaClient

client = TembaClient('rapidpro.io', open('token').read().strip())

# %%
stock_batch = next(client.get_runs(flow=u'a678268d-0e42-43f1-82cd-aa12117d145d').iterfetches(retry_on_rate_exceed=True))

# %%
stock_batch

# %%
stock = stock_batch[0]

# %%
stock.values
# Out:
# {u'confirm': <temba_client.v2.types.Value at 0x7eff7412ca90>,
#  u'f100stockalert': <temba_client.v2.types.Value at 0x7eff654ebb90>,
#  u'f75stockalert': <temba_client.v2.types.Value at 0x7eff7412cc10>,
#  u'postlevel': <temba_client.v2.types.Value at 0x7eff79d73250>,
#  u'route_by_level': <temba_client.v2.types.Value at 0x7eff654ebc10>,
#  u'route_by_type': <temba_client.v2.types.Value at 0x7eff7412c8d0>,
#  u'rutf_bal_carton': <temba_client.v2.types.Value at 0x7eff7412cbd0>,
#  u'rutf_bal_sachet': <temba_client.v2.types.Value at 0x7eff7412c910>,
#  u'rutf_in': <temba_client.v2.types.Value at 0x7eff7412c250>,
#  u'rutf_used_carton': <temba_client.v2.types.Value at 0x7eff7412c750>,
#  u'rutf_used_sachet': <temba_client.v2.types.Value at 0x7eff7412c7d0>,
#  u'rutfstockalert': <temba_client.v2.types.Value at 0x7eff654ebc90>,
#  u'weeknum': <temba_client.v2.types.Value at 0x7eff654ebb10>}

# %%
stock.id
# Out:
# 466049139
